# %%
print("hello Jupyter")
# Out:
# hello Jupyter

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
y=[3,15,7,28,30]

# %%
plt.plot(y)

# %%
x=(1,2,7,12,57)

# %%
y=np.sin(x)

# %%
len(y)
# Out:
# 5

# %%
plt.plot(x,y)
