# %% [markdown]
# ## 幫我做微積分作業

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sympy as sp

# %%
x=sp.symbols("x")
y=input("函數式：")
sp.plot(y)
# Out:
# 函數式：x**3+x**2+x*3+12
