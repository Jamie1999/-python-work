# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2,10,3,13,5])
# x自動會填上01234

# %%
randn(10)
# Out:
# array([ 0.31669362,  0.03519853, -0.64627707,  0.61046716,  0.66006133,
#        -1.07370554,  2.74404484,  1.58215029, -0.34521532, -1.20951359])

# %%
plot(randn(100))

# %%
plot([-2,1,2.7,3.3],[3,-5,6,0])

# %% [markdown]
# 自由作筆記

# %% [markdown]
# # 大標題

# %% [markdown]
# ## 次標題

# %% [markdown]
# ### 小標題

# %% [markdown]
# 內文在這裡。

# %% [markdown]
# ## 分次標題
# * jupyter notebook
# * pyton
# * panda
# * matplotlib

# %% [markdown]
# ## 網頁連結
#
# [政大mooc網](http://cou01.ewant.org/mod/ewantvideo/view.php?id=46820)

# %% [markdown]
# ## 插入圖片
# ![台灣黑熊](IMG_6111.jpeg)

# %%
# 插入圖片成功不了 因為我的電腦不能開起jupyter notebook 難不成是要逼我買新電腦？

# %% [markdown]
# ## 打數學符號
# 我們有一個函數$f(x)=x^3-2x^2+5$,我想給他積分:
#
# 就記得打上$(前後都要)
#
# $$\int_a^bf(x)\,dx$$

# %% [markdown]
# ## 數字變數

# %%
a=3

# %%
a+7
# Out:
# 10

# %%
a=87

# %%
a
# Out:
# 87

# %%
a**2
# Out:
# 7569

# %%
total=128+65+77

# %%
total
# Out:
# 270

# %%
total*30.5
# Out:
# 8235.0

# %% [markdown]
# ## 變數可以用中文

# %%
底=3
高=5

# %%
面積=底*高/2

# %%
面積
# Out:
# 7.5

# %% [markdown]
# ## 定義串列list

# %%
L=[3 ,9 ,10 , 2, -3, 5]

# %%
plot(L)

# %%
L=[3,87,-5,9]
G=[1 ,2 ,8 ,10]

# %%
L+G
# Out:
# [3, 87, -5, 9, 1, 2, 8, 10]

# %% [markdown]
# ## 純量乘法

# %%
L
# Out:
# [3, 87, -5, 9]

# %%
3*L
# Out:
# [3, 87, -5, 9, 3, 87, -5, 9, 3, 87, -5, 9]

# %%
##她不過就只是給我三次循環

# %% [markdown]
# ## Hello, World！

# %%
print("hello, world！")
# Out:
# hello, world！

# %%
name="Jamie"

# %%
print(name)
# Out:
# Jamie

# %%
name
# Out:
# 'Jamie'

# %%
##在pyton上，雙引號或單引號都可以

# %%
"helo " +name+ "!"
# Out:
# 'helo Jamie!'

# %%
name="john"

# %%
print("hello, "+name +"!")
# Out:
# hello, john!

# %%
hi="hi！"

# %%
hi+name
# Out:
# 'hi！john'

# %%
emoji=">~<"

# %%
5*emoji
# Out:
# '>~<>~<>~<>~<>~<'

# %% [markdown]
# ## 神奇三引號

# %%
message = '''我來示範一次
中間換行
像這樣
'''

# %%
print(message)
# Out:
# 我來示範一次
# 中間換行
# 像這樣

# %% [markdown]
# ## input指令

# %%
a = input("a = ")
# Out:
# a = 1

# %%
a
# Out:
# '1'

# %% [markdown]
# ## 匯率換算

# %%
m = input("美金價格")
twd=float(m)*30.5
print("合台幣" +str(twd) +"元")
#float是讓字串變成浮點數的標記，所以m就可以加減運算
# Out:
# 美金價格3984032
# 合台幣121512976.0元

# %%
twd
# Out:
# 121512976.0

# %%
#str是讓浮點數變成字串

# %%
message = input(">>")
print("拍拍")
# Out:
# >>q9 q9
# 拍拍
