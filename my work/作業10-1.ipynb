# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 春夏秋冬

# %%
num=150
while(True):
    x=np.random.random(200)
    y=np.random.random(200)
    t=x
    plt.scatter(x,y,s=100,c=t,cmap="spring")
    plt.show()
    a=input("你想繼續嗎？(y or n)")
    if a=="n"or a=="N":
        break
# Out:
# 你想繼續嗎？(y or n)n

# %%
num=150
while(True):
    x=np.random.random(150)
    y=np.random.random(150)
    t=x
    plt.scatter(x,y,s=100,c=t,cmap="summer")
    plt.show()
    a=input("你想繼續嗎？(y or n)")
    if a=="n"or a=="N":
        break
# Out:
# 你想繼續嗎？(y or n)n

# %%
num=200
while(True):
    x=np.random.random(100)
    y=np.random.random(100)
    t=x
    plt.scatter(x,y,s=100,c=t,cmap="autumn")
    plt.show()
    a=input("你想繼續嗎？(y or n)")
    if a=="n"or a=="N":
        break
# Out:
# 你想繼續嗎？(y or n)n

# %%
num=150
while(True):
    x=np.random.random(200)
    y=np.random.random(200)
    t=x
    plt.scatter(x,y,s=100,c=t,cmap="winter")
    plt.show()
    a=input("你想繼續嗎？(y or n)")
    if a=="n"or a=="N":
        break
# Out:
# 你想繼續嗎？(y or n)n
